# %% [markdown]
# # MATH50003 (2025–26)
# # Revision Lab

# %%
using LinearAlgebra, SetRounding, Test

# %% [markdown]
# **Problem 1(a)** Simpson's rule on a single panel is given by
# $$
# ∫_a^b f(x) {\rm d}x ≈ {b-a \over 6} \left[f(a) + 4 f\!\left({a+b \over 2}\right) + f(b) \right].
# $$
# Complete the implementation of `simpsonsrule` by dividing $[0,1]$ into grid points $x_0, x_1, …, x_{2n}$ with $x_k = k/(2n)$
# and applying Simpson's rule on the intervals $[x_{2k-2},x_{2k}]$ for $k = 1,…,n$.

# %%
function simpsonsrule(f, n)
    # TODO: implement Simpsons rule
    P = range(0, 1; length = 2*n+1)
    ret = 0.0
    for k=1:n
        a, b = P[2*k-1], P[2*k+1]
        ret += (b - a)/6 * (f(a) + 4*f((a+b)/2) + f(b))
    end
    ret
    

end

@test simpsonsrule(exp, 1000) ≈ exp(1)-1
# Out:
# Test Passed

# %% [markdown]
# **Problem 1(b)** By computing with various values of $n$, conjecture what the convergence rate is as $n → ∞$. Is it faster than Trapezium rules $O(n^{-2})$?

# %%
# TODO: vary n and deduce the converge rate, either by looking at errors or by plotting
using Plots
function rightrectangularrule(f, n) # create a function named "rightrectangularrule" that takes in two arguments
    ret = 0.0
    for j = 1:n
        ret = ret + f(j/n) # now f is the input function
    end
    ret/n   # the last line of a function is returned
end
errs = [abs(simpsonsrule(exp, n) - exp(1)+1) for n=1:1000]
plot(range(0,1; length=50), errs)
# Out:
# BoundsError: attempt to access 50-element StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64} at index [1:1000]
#
# Stacktrace:
#   [1] throw_boundserror(A::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, I::Tuple{UnitRange{Int64}})
#     @ Base .\essentials.jl:15
#   [2] checkbounds
#     @ .\abstractarray.jl:699 [inlined]
#   [3] getindex(r::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, s::UnitRange{Int64})
#     @ Base .\twiceprecision.jl:496
#   [4] gr_draw_segments(series::Plots.Series, x::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, y::Vector{Float64}, z::Nothing, fillrange::Nothing, clims::Tuple{Float64, Float64})
#     @ Plots C:\Users\jarlu\.julia\packages\Plots\xC48f\src\backends\gr.jl:1862
#   [5] gr_add_series(sp::Plots.Subplot{Plots.GRBackend}, series::Plots.Series)
#     @ Plots C:\Users\jarlu\.julia\packages\Plots\xC48f\src\backends\gr.jl:1779
#   [6] gr_display(sp::Plots.Subplot{Plots.GRBackend}, w::Measures.AbsoluteLength, h::Measures.AbsoluteLength, vp_canvas::Plots.GRViewport{Float64})
#     @ Plots C:\Users\jarlu\.julia\packages\Plots\xC48f\src\backends\gr.jl:970
#   [7] (::Plots.var"#gr_display##0#gr_display##1"{Int64, Int64, Plots.GRViewport{Float64}})(sp::Plots.Subplot{Plots.GRBackend})
#     @ Plots C:\Users\jarlu\.julia\packages\Plots\xC48f\src\backends\gr.jl:693
#   [8] foreach(f::Plots.var"#gr_display##0#gr_display##1"{Int64, Int64, Plots.GRViewport{Float64}}, itr::Vector{Plots.Subplot})
#     @ Base .\abstractarray.jl:3188
#   [9] gr_display(plt::Plots.Plot{Plots.GRBackend}, dpi_factor::Int64, display::Bool)
#     @ Plots C:\Users\jarlu\.julia\packages\Plots\xC48f\src\backends\gr.jl:693
#  [10] gr_display
#     @ C:\Users\jarlu\.julia\packages\Plots\xC48f\src\backends\gr.jl:660 [inlined]
#  [11] (::Plots.var"#_show##12#_show##13"{Plots.Plot{Plots.GRBackend}, String, Int64})()
#     @ Plots C:\Users\jarlu\.julia\packages\Plots\xC48f\src\backends\gr.jl:2104
#  [12] withenv(f::Plots.var"#_show##12#_show##13"{Plots.Plot{Plots.GRBackend}, String, Int64}, keyvals::Pair{String, String})
#     @ Base .\env.jl:265
#  [13] _show(io::IOContext{IOBuffer}, ::MIME{Symbol("image/svg+xml")}, plt::Plots.Plot{Plots.GRBackend})
#     @ Plots C:\Users\jarlu\.julia\packages\Plots\xC48f\src\backends\gr.jl:2097
#  [14] show(io::IOContext{IOBuffer}, m::MIME{Symbol("image/svg+xml")}, plt::Plots.Plot{Plots.GRBackend})
#     @ Plots C:\Users\jarlu\.julia\packages\Plots\xC48f\src\output.jl:239
#  [15] limitstringmime(mime::MIME{Symbol("image/svg+xml")}, x::Any, forcetext::Bool)
#     @ IJulia C:\Users\jarlu\.julia\packages\IJulia\TXScA\src\inline.jl:56
#  [16] limitstringmime
#     @ C:\Users\jarlu\.julia\packages\IJulia\TXScA\src\inline.jl:51 [inlined]
#  [17] display_mimestring(m::MIME{Symbol("image/svg+xml")}, x::Any)
#     @ IJulia C:\Users\jarlu\.julia\packages\IJulia\TXScA\src\display.jl:80
#  [18] _display_dict(x::Any)
#     @ IJulia C:\Users\jarlu\.julia\packages\IJulia\TXScA\src\display.jl:109
#  [19] display_dict(x::Any)
#     @ IJulia C:\Users\jarlu\.julia\packages\IJulia\TXScA\src\display.jl:133
#  [20] execute_request(socket::ZMQ.Socket, kernel::IJulia.Kernel, msg::IJulia.Msg)
#     @ IJulia C:\Users\jarlu\.julia\packages\IJulia\TXScA\src\execute_request.jl:181
#  [21] eventloop(socket::ZMQ.Socket, kernel::IJulia.Kernel)
#     @ IJulia C:\Users\jarlu\.julia\packages\IJulia\TXScA\src\eventloop.jl:26
#  [22] (::IJulia.var"#waitloop##2#waitloop##3"{IJulia.Kernel})()
#     @ IJulia C:\Users\jarlu\.julia\packages\IJulia\TXScA\src\eventloop.jl:71

# %% [markdown]
# **Problem 2** Consider a 3-term divided-difference approximation
# $$
# f'(x) ≈ {5f(x+2h) - 3f(x) - 2f(x-h) \over 12h}
# $$
# Implement this in the following function.

# %%
function threeterm_divideddifference(f, x, h)
    # TODO: Implement the above divided-difference formula
    return (5*f(x+2*h) -3*f(x) -2*f(x-h))/(12*h)

end
@test threeterm_divideddifference(exp, 0, 0.0000001) ≈ 1 atol=1E-5
# Out:
# Test Passed

# %% [markdown]
# **Problem 3** Using the following simplified `Dual` implementation, consider a double-dual number
# like `Dual(Dual(a,b), Dual(c,d))`. By choosing `a`, `b`, `c` and `d`, construct the function `secondderivative(f, x)`
# that computes the second derivative of a function. Hint: it might help to think of a double-dual number as
# $(a + b*ε) + δ*(c + d*ε)$ where $ε^2 = δ^2 = 0$.

# %%
struct Dual
    a
    b
end

import Base: +, *, exp
function +(x::Dual, y::Dual)
    a,b = x.a, x.b # x == a+bϵ. This gets out a and b
    c,d = y.a, y.b # y == c+dϵ. This gets out c and d
    Dual(a+c, b+d)
end
function *(x::Dual, y::Dual)
    a,b = x.a, x.b # x == a+bϵ. This gets out a and b
    c,d = y.a, y.b # y == c+dϵ. This gets out c and d
    Dual(a*c, b*c + a*d)
end
exp(x::Dual) = Dual(exp(x.a), exp(x.a) * x.b)


function secondderivative(f, x)
    # TODO: compute the second derivative of f using a double-dual number.
    d = Dual(x, 1)
    first = f(d).b
    ret = f(Dual(first,1)).b
    ret
    

end

f = x -> exp(x*exp(x))
@test secondderivative(f, 0) ≈ 3
# Out:
# Test Failed at In[10]:31
#   Expression: secondderivative(f, 0) ≈ 3
#    Evaluated: 82.38711134943223 ≈ 3
# There was an error during testing
#
# Stacktrace:
#  [1] record(ts::Test.FallbackTestSet, t::Union{Test.Error, Test.Fail})
#    @ Test C:\Users\jarlu\.julia\juliaup\julia-1.12.4+0.x64.w64.mingw32\share\julia\stdlib\v1.12\Test\src\Test.jl:1030
#  [2] do_test(result::Test.ExecutionResult, orig_expr::Any)
#    @ Test C:\Users\jarlu\.julia\juliaup\julia-1.12.4+0.x64.w64.mingw32\share\julia\stdlib\v1.12\Test\src\Test.jl:713
#  [3] top-level scope
#    @ In[10]:31
#  [4] macro expansion
#    @ C:\Users\jarlu\.julia\juliaup\julia-1.12.4+0.x64.w64.mingw32\share\julia\stdlib\v1.12\Test\src\Test.jl:680 [inlined]
#  [5] eval(m::Module, e::Any)
#    @ Core .\boot.jl:489

# %% [markdown]
# **Problem 4** Implement the `sqrt` function with correctly rounded interval arithmetic.

# %%
struct Interval # represents the set [a,b]
    a # left endpoint
    b # right endpoint
end

Interval(x) = Interval(x,x) # Support Interval(1) to represent [1,1]

import Base: sqrt, in
in(x, X::Interval) = X.a ≤ x ≤ X.b

function sqrt(X::Interval)
    a,b = promote(X.a, X.b) # make sure all are the same type
    T = typeof(a)
    # TODO: implement sqrt by correctly rounding the computation.
    α = setrounding(T, RoundDown) do
        sqrt(a)
    end
    β = setrounding(T, RoundUp) do
        sqrt(b)
    end
    Interval(α, β)

end

@test sqrt(big(2.0)) in sqrt(Interval(2.0))
# Out:
# Test Passed

# %% [markdown]
# **Problem 5** A one-hot vector is a concept used in machine learning to define a vector with a single non-zero entry.
# Complete the following data structure representing the vector $c 𝐞_j ∈ ℝ^n$.

# %%
struct OneHotVector <: AbstractVector{Float64}
    c::Float64 # value at j
    j::Int # index that is nonzero
    n::Int # length of vector
end

import Base: size, getindex
size(a::OneHotVector) = (a.n,)

function getindex(a::OneHotVector, k::Int)
    if k ≤ 0 || k > a.n
        error("dimension mismatch")
    end
    # TODO: return the entry of a in the kth index
    if k == a.j
        a.c
    else
        0
    end

end

@test OneHotVector(1.5, 2, 4) == [0,1.5,0,0]
# Out:
# Test Passed

# %% [markdown]
# **Problem 6** Implement `reversecholesky(A)` that returns an upper-triangular matrix `U` such that `U*U' ≈ A`.
# You may assume the input is symmetric positive definite and has `Float64` values. You must not use the inbuilt `cholesky`
# function or in any other way reduce the problem to a standard Cholesky factorisation.

# %%
function reversecholesky(A)
    n,m = size(A)
    if n ≠ m
        error("Matrix must be square")
    end
    if A ≠ A'
        error("Matrix must be symmetric")
    end
    U = UpperTriangular(zeros(n,n))
    # TODO: populate U so that U'U ≈ A
    A_j = A
    for j=n:-1:1
        α, 𝐯 = A_j[j,j], A_j[1:j-1, j]
        U[j,j] = sqrt(α)
        U[1:j-1, j] = 𝐯/U[j,j]
        A_j = A_j[1:j-1,1:j-1] - (𝐯 * 𝐯')/α
    end
    
            
        
    

    U
end

A = [2 1 0; 1 2 1; 0 1 2]
U = reversecholesky(A)
@test U*U' ≈ A
# Out:
# Test Passed

# %% [markdown]
# **Problem 7(a)**  Construct a reverse Householder reflection, that gives an orthogonal matrix
# $Q$ such that, for $𝐱 ∈ ℝ^n$,
# $$
# 𝐱^⊤ Q = \|𝐱\|𝐞_1^⊤.
# $$

# %%
function reversehouseholderreflection(x)
    # TODO: implement a Householder reflection that acts on the left
    n = length(x)
    e1 = zeros(eltype(x), n)
    e1[1] = 1
    y = -sign(x[1]) * norm(x) * e1 + x
    w = y/norm(y)
    Id = Matrix(I, n, n)
    transpose(Id - 2 * w * w')

end

x = randn(5)
Q = reversehouseholderreflection(x)
@test x'Q ≈ [norm(x) zeros(1,4)]
# Out:
# Test Passed

# %% [markdown]
# **Problem 7(b)**
# Complete the function `lq(A)` that
# returns a LQ factorisation, that is, `A = LQ` where  `L` is lower triangular and `Q` is an orthogonal
# matrix. You may assume that `A` is a square `Matrix{Float64}`.  Do not manipulate the problem
# to reduce it to a standard QR factorisation.

# %%
function lq(A)
    m,n = size(A)
    m == n || error("not square")
    # TODO Create Q and L such that A = L*Q, Q'Q == I and L is lower triangular
    L = copy(A)
    Q = Matrix(1.0I, n, n)
    for k = 1:n-1
        x = L[k, k:end]
        Qk = reversehouseholderreflection(x)
        L[k:end, k:end] = L[k:end, k:end] * Qk
        Q[k:end, :] = Qk * Q[k:end, :]
    end
    L, Q
        
    

end

A = [1.0 2 3; 1 4 9; 1 1 1]
L,Q = lq(A)
@test Q'Q ≈ I
@test L*Q ≈ A
@test L ≈ tril(L) # it is acceptable to have small non-zero entries in L
# Out:
# Test Passed

# %% [markdown]
# **Problem 8** Complete the function `lagrangebasis(g, k, x)` where `g` is a vector of grid
# points, that computes the Lagrange basis function at the point `x`. You may assume all numbers
# are `Float64`.

# %%
function lagrangebasis(g::AbstractVector, k, x)
    n = length(g) # number of points
    ## TODO: compute ℓ_k(x) corresponding to the grid g
    l_k = 1 
    for j=1:n
        if j != k
            l_k *= (x-g[j])/(g[k] - g[j])
        end
    end
    l_k
        

end

g = 1:5
@test lagrangebasis(g, 2, 2) == 1
@test lagrangebasis(g, 2, 3) == lagrangebasis(g, 2, 4) ==  0
@test lagrangebasis(g, 3, 0.1) ≈ 8.169525
# Out:
# Test Passed

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
